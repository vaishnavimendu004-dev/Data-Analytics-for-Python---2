# %%
import pandas as pd

# %%
import numpy as np

# %%
data={"Region":["Asia","Asia","Europe","Europe","North America","South America"],"Country":["China","India","France","UK","Canada","Brazil"],"Year":[2025,2023,2024,2022,2021,2025],"Sales":[20000,30000,40000,50000,60000,70000],"Profit":[300,400,500,600,700,800]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#           Region Country  Year  Sales  Profit
# 0           Asia   China  2025  20000     300
# 1           Asia   India  2023  30000     400
# 2         Europe  France  2024  40000     500
# 3         Europe      UK  2022  50000     600
# 4  North America  Canada  2021  60000     700
# 5  South America  Brazil  2025  70000     800

# %%
df.groupby("Region")[["Profit","Year"]].mean()
# Out:
#                Profit    Year
# Region
# Asia            350.0  2024.0
# Europe          550.0  2023.0
# North America   700.0  2021.0
# South America   800.0  2025.0

# %%
df[(df['Sales']>300)]
# Out:
#           Region Country  Year  Sales  Profit
# 0           Asia   China  2025  20000     300
# 1           Asia   India  2023  30000     400
# 2         Europe  France  2024  40000     500
# 3         Europe      UK  2022  50000     600
# 4  North America  Canada  2021  60000     700
# 5  South America  Brazil  2025  70000     800

# %%
ice_cream=["strawberry","chocolate","butterscotch","vanilla","caramel"]

# %%
pd.Series(ice_cream)
# Out:
# 0      strawberry
# 1       chocolate
# 2    butterscotch
# 3         vanilla
# 4         caramel
# dtype: object

# %%
ic_sales=[25000,30000,78000,45000,59000]

# %%
pd.Series(ic_sales)
# Out:
# 0    25000
# 1    30000
# 2    78000
# 3    45000
# 4    59000
# dtype: int64

# %%
ic_id=[2.5,3.4,7.5,8.9]

# %%
pd.Series(ic_id)
# Out:
# 0    2.5
# 1    3.4
# 2    7.5
# 3    8.9
# dtype: float64

# %%
sushi={"Salmon":"Orange","Tuna":"Pink","Eel":"White"}

# %%
pd.Series(sushi)
# Out:
# Salmon    Orange
# Tuna        Pink
# Eel        White
# dtype: object

# %%
#Methods in Series
price=pd.Series([23.5,45.6,75.8,23.4])

# %%
price
# Out:
# 0    23.5
# 1    45.6
# 2    75.8
# 3    23.4
# dtype: float64

# %%
price.sum()
# Out:
# 168.29999999999998

# %%
price.mean()
# Out:
# 42.074999999999996

# %%
price.product()
# Out:
# 1900718.3520000002

# %%
price.std()
# Out:
# 24.78969880145111

# %%
adjectives=pd.Series(["Beautiful","Smart","Handsome","Smart"]) #Method
adjectives
# Out:
# 0    Beautiful
# 1        Smart
# 2     Handsome
# 3        Smart
# dtype: object

# %%
adjectives.size
# Out:
# 4

# %%
adjectives.values
# Out:
# array(['Beautiful', 'Smart', 'Handsome', 'Smart'], dtype=object)

# %%
adjectives.is_unique
# Out:
# False

# %%
type(adjectives.values)
# Out:
# numpy.ndarray

# %%
days=["monday","tuesday","wednesday","thursday","friday","saturday","sunday"]
fruits=["apple","banana","pineapple","guava","litchi","grapes","mango"]

# %%
pd.Series(days,fruits) #passing parameter argument
# Out:
# apple           monday
# banana         tuesday
# pineapple    wednesday
# guava         thursday
# litchi          friday
# grapes        saturday
# mango           sunday
# dtype: object

# %%
pd.Series(index=fruits,data=days)
# Out:
# apple           monday
# banana         tuesday
# pineapple    wednesday
# guava         thursday
# litchi          friday
# grapes        saturday
# mango           sunday
# dtype: object
