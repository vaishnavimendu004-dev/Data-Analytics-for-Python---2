# %%
import pandas as pd

# %%
import numpy as np

# %%
pokemon=pd.read_csv(r"C:\Users\Vaishnavi\Downloads\pokemon.csv",usecols=["Name"]).squeeze("columns") #Squeeze funtion used to convert dataframe into series

# %%
pokemon
# Out:
# 0          Bulbasaur
# 1            Ivysaur
# 2           Venusaur
# 3         Charmander
# 4         Charmeleon
#             ...
# 1005    Iron Valiant
# 1006        Koraidon
# 1007        Miraidon
# 1008    Walking Wake
# 1009     Iron Leaves
# Name: Name, Length: 1010, dtype: object

# %%
len(pokemon)
sorted(pokemon)
# Out:
# ['Abomasnow',
#  'Abra',
#  'Absol',
#  'Accelgor',
#  'Aegislash',
#  'Aerodactyl',
#  'Aggron',
#  'Aipom',
#  'Alakazam',
#  'Alcremie',
#  'Alomomola',
#  'Altaria',
#  'Amaura',
#  'Ambipom',
#  'Amoonguss',
#  'Ampharos',
#  'Annihilape',
#  'Anorith',
#  'Appletun',
#  'Applin',
#  'Araquanid',
#  'Arbok',
#  'Arboliva',
#  'Arcanine',
#  'Arceus',
#  'Archen',
#  'Archeops',
#  'Arctibax',
#  'Arctovish',
#  'Arctozolt',
#  'Ariados',
#  'Armaldo',
#  'Armarouge',
#  'Aromatisse',
#  'Aron',
#  'Arrokuda',
#  'Articuno',
#  'Audino',
#  'Aurorus',
#  'Avalugg',
#  'Axew',
#  'Azelf',
#  'Azumarill',
#  'Azurill',
#  'Bagon',
#  'Baltoy',
#  'Banette',
#  'Barbaracle',
#  'Barboach',
#  'Barraskewda',
#  'Basculegion',
#  'Basculin',
#  'Bastiodon',
#  'Baxcalibur',
#  'Bayleef',
#  'Beartic',
#  'Beautifly',
#  'Beedrill',
#  'Beheeyem',
#  'Beldum',
#  'Bellibolt',
#  'Bellossom',
#  'Bellsprout',
#  'Bergmite',
#  'Bewear',
#  'Bibarel',
#  'Bidoof',
#  'Binacle',
# ...

# %%
list(pokemon)
# Out:
# ['Bulbasaur',
#  'Ivysaur',
#  'Venusaur',
#  'Charmander',
#  'Charmeleon',
#  'Charizard',
#  'Squirtle',
#  'Wartortle',
#  'Blastoise',
#  'Caterpie',
#  'Metapod',
#  'Butterfree',
#  'Weedle',
#  'Kakuna',
#  'Beedrill',
#  'Pidgey',
#  'Pidgeotto',
#  'Pidgeot',
#  'Rattata',
#  'Raticate',
#  'Spearow',
#  'Fearow',
#  'Ekans',
#  'Arbok',
#  'Pikachu',
#  'Raichu',
#  'Sandshrew',
#  'Sandslash',
#  'Nidoran♀',
#  'Nidorina',
#  'Nidoqueen',
#  'Nidoran♂',
#  'Nidorino',
#  'Nidoking',
#  'Clefairy',
#  'Clefable',
#  'Vulpix',
#  'Ninetales',
#  'Jigglypuff',
#  'Wigglytuff',
#  'Zubat',
#  'Golbat',
#  'Oddish',
#  'Gloom',
#  'Vileplume',
#  'Paras',
#  'Parasect',
#  'Venonat',
#  'Venomoth',
#  'Diglett',
#  'Dugtrio',
#  'Meowth',
#  'Persian',
#  'Psyduck',
#  'Golduck',
#  'Mankey',
#  'Primeape',
#  'Growlithe',
#  'Arcanine',
#  'Poliwag',
#  'Poliwhirl',
#  'Poliwrath',
#  'Abra',
#  'Kadabra',
#  'Alakazam',
#  'Machop',
#  'Machoke',
#  'Machamp',
# ...

# %%
pokemon.shape
# Out:
# (1010,)

# %%
min(pokemon)
# Out:
# 'Abomasnow'

# %%
max(pokemon)
# Out:
# 'Zygarde'

# %%
google=pd.read_csv(r"C:\Users\Vaishnavi\Downloads\google_stock_price.csv")

# %%
google
# Out:
#             Date       Price
# 0     2004-08-19    2.490664
# 1     2004-08-20    2.515820
# 2     2004-08-23    2.758411
# 3     2004-08-24    2.770615
# 4     2004-08-25    2.614201
# ...          ...         ...
# 4788  2023-08-28  132.080002
# 4789  2023-08-29  132.998001
# 4790  2023-08-30  135.570007
# 4791  2023-08-31  137.050003
# 4792  2023-09-01  138.429993
#
# [4793 rows x 2 columns]

# %%
google.info
# Out:
# <bound method DataFrame.info of             Date       Price
# 0     2004-08-19    2.490664
# 1     2004-08-20    2.515820
# 2     2004-08-23    2.758411
# 3     2004-08-24    2.770615
# 4     2004-08-25    2.614201
# ...          ...         ...
# 4788  2023-08-28  132.080002
# 4789  2023-08-29  132.998001
# 4790  2023-08-30  135.570007
# 4791  2023-08-31  137.050003
# 4792  2023-09-01  138.429993
#
# [4793 rows x 2 columns]>

# %%
google.shape
# Out:
# (4793, 2)

# %%
nba=pd.read_csv(r"C:\Users\Vaishnavi\Downloads\nba.csv")

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# 3      Elan Chalon  20616000.0
# ...

# %%
nba.info
# Out:
# <bound method DataFrame.info of                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary
# 0        Villanova   4556983.0
# 1       Fenerbahce  18700000.0
# 2         Michigan   4094244.0
# ...

# %%
nba.shape
# Out:
# (592, 7)

# %%
nba.head()
# Out:
#                 Name           Team Position Height  Weight      College  \
# 0         Saddiq Bey  Atlanta Hawks        F    6-7   215.0    Villanova
# 1  Bogdan Bogdanovic  Atlanta Hawks        G    6-5   225.0   Fenerbahce
# 2        Kobe Bufkin  Atlanta Hawks        G    6-5   195.0     Michigan
# 3       Clint Capela  Atlanta Hawks        C   6-10   256.0  Elan Chalon
# 4     Bruno Fernando  Atlanta Hawks      F-C   6-10   240.0     Maryland
#
#        Salary
# 0   4556983.0
# 1  18700000.0
# 2   4094244.0
# 3  20616000.0
# 4   2581522.0

# %%
nba.sort_index(ascending=False)
# Out:
#                   Name                Team Position Height  Weight  \
# 591                NaN                 NaN      NaN    NaN     NaN
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# ..                 ...                 ...      ...    ...     ...
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
#
#            College      Salary
# 591            NaN         NaN
# 590           Utah   8195122.0
# 589    Real Madrid         NaN
# 588  Wichita State  10250000.0
# ...

# %%
nba.sort_values(["Team","Position"],ascending=True)
# Out:
#                Name                Team Position Height  Weight  \
# 3      Clint Capela       Atlanta Hawks        C   6-10   256.0
# 0        Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 6        AJ Griffin       Atlanta Hawks        F    6-6   220.0
# 7    Mouhamed Gueye       Atlanta Hawks        F   6-11   210.0
# 9     Jalen Johnson       Atlanta Hawks        F    6-8   219.0
# ..              ...                 ...      ...    ...     ...
# 586    Jordan Poole  Washington Wizards        G    6-4   194.0
# 587    Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588   Landry Shamet  Washington Wizards        G    6-4   190.0
# 590    Delon Wright  Washington Wizards        G    6-5   185.0
# 591             NaN                 NaN      NaN    NaN     NaN
#
#               College      Salary
# 3         Elan Chalon  20616000.0
# 0           Villanova   4556983.0
# 6                Duke   3712920.0
# 7    Washington State   1119563.0
# ...

# %%
Double_Salary=nba["Salary"]*2

# %%
Double_Salary
# Out:
# 0       9113966.0
# 1      37400000.0
# 2       8188488.0
# 3      41232000.0
# 4       5163044.0
#           ...
# 587     3439728.0
# 588    20500000.0
# 589           NaN
# 590    16390244.0
# 591           NaN
# Name: Salary, Length: 592, dtype: float64

# %%
nba[["feet","inch"]]=nba["Height"].str.split("-",expand=True)

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary feet inch
# 0        Villanova   4556983.0    6    7
# 1       Fenerbahce  18700000.0    6    5
# ...

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    object
#  2   Position  584 non-null    object
#  3   Height    585 non-null    object
#  4   Weight    584 non-null    float64
#  5   College   578 non-null    object
#  6   Salary    488 non-null    float64
#  7   feet      585 non-null    object
#  8   inch      585 non-null    object
# dtypes: float64(2), object(7)
# memory usage: 41.8+ KB

# %%
nba[["feet","inch"]]=nba[["feet","inch"]].apply(pd.to_numeric)

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 592 entries, 0 to 591
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      591 non-null    object
#  1   Team      591 non-null    object
#  2   Position  584 non-null    object
#  3   Height    585 non-null    object
#  4   Weight    584 non-null    float64
#  5   College   578 non-null    object
#  6   Salary    488 non-null    float64
#  7   feet      585 non-null    float64
#  8   inch      585 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 41.8+ KB

# %%
nba["feet"]*30.48+nba["inch"]*2.54
# Out:
# 0      200.66
# 1      195.58
# 2      195.58
# 3      208.28
# 4      208.28
#         ...
# 587    190.50
# 588    193.04
# 589    208.28
# 590    195.58
# 591       NaN
# Length: 592, dtype: float64

# %%
nba["Height_cm"]=nba["feet"]*30.48+nba["inch"]*2.54

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary  feet  inch  Height_cm
# 0        Villanova   4556983.0   6.0   7.0     200.66
# ...

# %%
nba.drop("Height_cm",axis=1)
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary  feet  inch
# 0        Villanova   4556983.0   6.0   7.0
# 1       Fenerbahce  18700000.0   6.0   5.0
# ...

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary  feet  inch  Height_cm
# 0        Villanova   4556983.0   6.0   7.0     200.66
# ...

# %%
nba.drop(2) #To drop a single row across the dataset
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# 5        Trent Forrest       Atlanta Hawks        G    6-4   210.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary  feet  inch  Height_cm
# 0        Villanova   4556983.0   6.0   7.0     200.66
# ...

# %%
nba.insert(7,"Vaishnavi",0) #inserting column

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary  Vaishnavi  feet  inch  Height_cm
# 0        Villanova   4556983.0          0   6.0   7.0     200.66
# ...

# %%
nba.dropna(axis=0,how="all").shape
# Out:
# (592, 11)

# %%
nba
# Out:
#                   Name                Team Position Height  Weight  \
# 0           Saddiq Bey       Atlanta Hawks        F    6-7   215.0
# 1    Bogdan Bogdanovic       Atlanta Hawks        G    6-5   225.0
# 2          Kobe Bufkin       Atlanta Hawks        G    6-5   195.0
# 3         Clint Capela       Atlanta Hawks        C   6-10   256.0
# 4       Bruno Fernando       Atlanta Hawks      F-C   6-10   240.0
# ..                 ...                 ...      ...    ...     ...
# 587       Ryan Rollins  Washington Wizards        G    6-3   180.0
# 588      Landry Shamet  Washington Wizards        G    6-4   190.0
# 589   Tristan Vukcevic  Washington Wizards        F   6-10   220.0
# 590       Delon Wright  Washington Wizards        G    6-5   185.0
# 591                NaN                 NaN      NaN    NaN     NaN
#
#            College      Salary  Vaishnavi  feet  inch  Height_cm
# 0        Villanova   4556983.0          0   6.0   7.0     200.66
# ...

# %%
nba.dropna(axis=1,how="any").shape
# Out:
# (592, 1)

# %%
nba.dropna(axis=1,how="all").shape
# Out:
# (592, 11)

# %%
nba.isna() #To identify missing values
# Out:
#       Name   Team  Position  Height  Weight  College  Salary  Vaishnavi  \
# 0    False  False     False   False   False    False   False      False
# 1    False  False     False   False   False    False   False      False
# 2    False  False     False   False   False    False   False      False
# 3    False  False     False   False   False    False   False      False
# 4    False  False     False   False   False    False   False      False
# ..     ...    ...       ...     ...     ...      ...     ...        ...
# 587  False  False     False   False   False    False   False      False
# 588  False  False     False   False   False    False   False      False
# 589  False  False     False   False   False    False    True      False
# 590  False  False     False   False   False    False   False      False
# 591   True   True      True    True    True     True    True      False
#
#       feet   inch  Height_cm
# 0    False  False      False
# 1    False  False      False
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 nba[(nba["Salary"]>4000000) & (nba["Salary"]<5000000)]
#
# NameError: name 'nba' is not defined
