# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\Vaishnavi\Downloads\Piece_Dim - Piece_Dim.csv")

# %%
df
# Out:
#     Item_No  Length  Width  Height Operator
# 0    Item-1  102.67  49.53   19.69     Op-1
# 1    Item-2  102.50  51.42   19.63     Op-1
# 2    Item-3   95.37  52.25   21.51     Op-1
# 3    Item-4   94.77  49.24   18.60     Op-1
# 4    Item-5  104.26  47.90   19.46     Op-1
# 5    Item-6  105.18  49.39   20.36     Op-1
# 6    Item-7   97.35  48.05   20.22     Op-1
# 7    Item-8   99.35  44.59   21.03     Op-1
# 8    Item-9   90.62  47.29   19.78     Op-1
# 9   Item-10   97.22  52.14   20.71     Op-1
# 10  Item-11  100.00  54.76   20.62     Op-1
# 11  Item-12   97.23  48.26   19.51     Op-1
# 12  Item-13  105.72  50.04   20.06     Op-1
# 13  Item-14   89.82  45.98   20.30     Op-1
# 14  Item-15   99.17  53.54   20.25     Op-1
# 15  Item-16   95.51  45.36   20.52     Op-1
# 16  Item-17  107.69  48.18   19.33     Op-1
# 17  Item-18  106.83  50.81   19.12     Op-1
# 18  Item-19   98.73  55.76   19.37     Op-1
# 19  Item-20   94.31  48.74   18.80     Op-1
# ...

# %%
sns.displot(data=df,x="Length")
plt.title("Histogram")
plt.show()

# %%
sns.displot(data=df,x="Length", hue="Operator")
plt.title("Histogram")
plt.show()

# %%
sns.displot(data=df,x="Length", col="Operator")

plt.show()

# %%
sns.displot(data=df,x="Length", col="Operator", kind="kde")
plt.show()

# %%
sns.displot(data=df,x="Length", rug=True,kind="kde")

plt.show()

# %%
sns.displot(data=df,x="Length", col="Operator", kind="kde", hue="Operator", rug=True)
plt.show()

# %%
sns.displot(data=df,x="Length", kind="kde", hue="Operator", rug=True)
plt.show()

# %%
sns.displot(data=df,x="Length", col="Operator", kind="ecdf", hue="Operator", rug=True)
plt.show()

# %%
sns.displot(data=df,x="Length", kde=True, rug=True)
plt.show()

# %%
sns.displot(data=df,x="Length", y="Width")
plt.show()

# %%
sns.displot(data=df,x="Length", y="Width", kind="kde",)
plt.show()

# %%
sns.catplot(data=df,x="Operator", y="Length")
plt.show()
